# %%
import tensorflow as tf
import cv2
import numpy as np
import os
import random
import sys
from sklearn.model_selection import train_test_split

my_faces_path = '/home/weifeng/learngit/tf/人脸识别/my_faces'
other_faces_path = '/home/weifeng/learngit/tf/人脸识别/other_face'
size = 64

imgs = []
labs = []

def getPaddingSize(img):
    h, w, _ = img.shape
    top, bottom, left, right = (0,0,0,0)
    longest = max(h, w)

    if w < longest:
        tmp = longest - w
        # //表示整除符号
        left = tmp // 2
        right = tmp - left
    elif h < longest:
        tmp = longest - h
        top = tmp // 2
        bottom = tmp - top
    else:
        pass
    return top, bottom, left, right

def readData(path , h=size, w=size):
    for filename in os.listdir(path):
        if filename.endswith('.jpg'):
            filename = path + '/' + filename

            img = cv2.imread(filename)

            top,bottom,left,right = getPaddingSize(img)
            # 将图片放大， 扩充图片边缘部分
            img = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=[0,0,0])
            img = cv2.resize(img, (h, w))

            imgs.append(img)
            labs.append(path)

readData(my_faces_path)
readData(other_faces_path)
# 将图片数据与标签转换成数组
imgs = np.array(imgs)
labs = np.array([[0,1] if lab == my_faces_path else [1,0] for lab in labs])
# 随机划分测试集与训练集
train_x,test_x,train_y,test_y = train_test_split(imgs, labs, test_size=0.05, random_state=random.randint(0,100))
# 参数：图片数据的总数，图片的高、宽、通道
train_x = train_x.reshape(train_x.shape[0], size, size, 3)
test_x = test_x.reshape(test_x.shape[0], size, size, 3)
# 将数据转换成小于1的数
train_x = train_x.astype('float32')/255.0
test_x = test_x.astype('float32')/255.0

print('train size:%s, test size:%s' % (len(train_x), len(test_x)))
# 图片块，每次取100张图片
batch_size = 100
num_batch = len(train_x) // batch_size

x = tf.placeholder(tf.float32, [None, size, size, 3])
y_ = tf.placeholder(tf.float32, [None, 2])

keep_prob_5 = tf.placeholder(tf.float32)
keep_prob_75 = tf.placeholder(tf.float32)

def weightVariable(shape):
    init = tf.random_normal(shape, stddev=0.01)
    return tf.Variable(init)

def biasVariable(shape):
    init = tf.random_normal(shape)
    return tf.Variable(init)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1,1,1,1], padding='SAME')

def maxPool(x):
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

def dropout(x, keep):
    return tf.nn.dropout(x, keep)

def cnnLayer():
    # 第一层
    W1 = weightVariable([3,3,3,32]) # 卷积核大小(3,3)， 输入通道(3)， 输出通道(32)
    b1 = biasVariable([32])
    # 卷积
    conv1 = tf.nn.relu(conv2d(x, W1) + b1)
    # 池化
    pool1 = maxPool(conv1)
    # 减少过拟合，随机让某些权重不更新
    drop1 = dropout(pool1, keep_prob_5)

    # 第二层
    W2 = weightVariable([3,3,32,64])
    b2 = biasVariable([64])
    conv2 = tf.nn.relu(conv2d(drop1, W2) + b2)
    pool2 = maxPool(conv2)
    drop2 = dropout(pool2, keep_prob_5)

    # 第三层
    W3 = weightVariable([3,3,64,64])
    b3 = biasVariable([64])
    conv3 = tf.nn.relu(conv2d(drop2, W3) + b3)
    pool3 = maxPool(conv3)
    drop3 = dropout(pool3, keep_prob_5)

    # 全连接层
    Wf = weightVariable([8*16*32, 512])
    bf = biasVariable([512])
    drop3_flat = tf.reshape(drop3, [-1, 8*16*32])
    dense = tf.nn.relu(tf.matmul(drop3_flat, Wf) + bf)
    dropf = dropout(dense, keep_prob_75)

    # 输出层
    Wout = weightVariable([512,2])
    bout = weightVariable([2])
    #out = tf.matmul(dropf, Wout) + bout
    out = tf.add(tf.matmul(dropf, Wout), bout)
    return out
# Out:
# train size:1900, test size:100

# %%
out = cnnLayer()
predict = tf.argmax(out,1)

# %%
saver = tf.train.Saver()
sess = tf.Session()
saver.restore(sess,tf.train.latest_checkpoint('/home/weifeng/learngit/'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e59717cbc849> in <module>()
# ----> 1 saver = tf.train.Saver()
#       2 sess = tf.Session()
#       3 saver.restore(sess,tf.train.latest_checkpoint('/home/weifeng/learngit/'))
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in __init__(self, var_list, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, saver_def, builder, defer_build, allow_empty, write_version, pad_step_number, save_relative_paths, filename)
#    1312           time.time() + self._keep_checkpoint_every_n_hours * 3600)
#    1313     elif not defer_build:
# -> 1314       self.build()
#    1315     if self.saver_def:
#    1316       self._check_saver_def()
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in build(self)
#    1321     if context.executing_eagerly():
#    1322       raise RuntimeError("Use save/restore instead of build in eager mode.")
# -> 1323     self._build(self._filename, build_save=True, build_restore=True)
#    1324
#    1325   def _build_eager(self, checkpoint_path, build_save, build_restore):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in _build(self, checkpoint_path, build_save, build_restore)
#    1358           restore_sequentially=self._restore_sequentially,
#    1359           filename=checkpoint_path,
# -> 1360           build_save=build_save, build_restore=build_restore)
#    1361     elif self.saver_def and self._name:
#    1362       # Since self._name is used as a name_scope by builder(), we are
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in _build_internal(self, names_to_saveables, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, filename, build_save, build_restore)
#     787                        " when eager execution is not enabled.")
#     788
# --> 789     saveables = self._ValidateAndSliceInputs(names_to_saveables)
#     790     if max_to_keep is None:
#     791       max_to_keep = 0
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in _ValidateAndSliceInputs(self, names_to_saveables)
#     635     """
#     636     if not isinstance(names_to_saveables, dict):
# --> 637       names_to_saveables = BaseSaverBuilder.OpListToDict(names_to_saveables)
#     638
#     639     saveables = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in OpListToDict(op_list, convert_variable_to_tensor)
#     612           if name in names_to_saveables:
#     613             raise ValueError("At least two variables have the same name: %s" %
# --> 614                              name)
#     615           names_to_saveables[name] = var
#     616
#
# ValueError: At least two variables have the same name: Variable/Adam
